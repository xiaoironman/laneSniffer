# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
plt.xkcd()

# %%
#Capture livestream video content from camera 0
cap = cv2.VideoCapture(0)
_, frame = cap.read()

# %%
plt.imshow(frame)

# %%
try:
    x = 1
except TypeError:
    pass

# %%
import cv2

# %%
cv2.namedWindow('maran')

# %%
def getLines(img):
    rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    #plt.imshow( rgb )
    #plt.show()
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray,225,250)
    lines = cv2.HoughLines(edges,1,np.pi/180, 200)
    try:
        for l in lines:
            for r,theta in l:

                # Stores the value of cos(theta) in a
                a = np.cos(theta)

                # Stores the value of sin(theta) in b
                b = np.sin(theta)

                # x0 stores the value rcos(theta)
                x0 = a*r

                # y0 stores the value rsin(theta)
                y0 = b*r

                # x1 stores the rounded off value of (rcos(theta)-1000sin(theta))
                x1 = int(x0 + 1000*(-b))

                # y1 stores the rounded off value of (rsin(theta)+1000cos(theta))
                y1 = int(y0 + 1000*(a))

                # x2 stores the rounded off value of (rcos(theta)+1000sin(theta))
                x2 = int(x0 - 1000*(-b))

                # y2 stores the rounded off value of (rsin(theta)-1000cos(theta))
                y2 = int(y0 - 1000*(a))

                # cv2.line draws a line in img from the point(x1,y1) to (x2,y2).
                # (0,0,255) denotes the colour of the line to be
                #drawn. In this case, it is red.
                cv2.line(img,(x1,y1), (x2,y2), (0,0,0),2)
    except TypeError:
        pass
    return img

# %%
plt.imshow(getLines(frame))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-78f283abaad1> in <module>
# ----> 1 plt.imshow(getLines(frame))
#
# <ipython-input-5-2f5d066f629c> in getLines(img)
#       1 def getLines(img):
# ----> 2     rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#       3     #plt.imshow( rgb )
#       4     #plt.show()
#       5     gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#
# error: OpenCV(4.1.2) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
plt.imshow(hsv)

# %%
sobelx = cv2.Sobel(frame,cv2.CV_64F,1,0,ksize=5)
plt.imshow(sobelx)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
sobely = cv2.Sobel(frame,cv2.CV_64F,0,1,ksize=5)
plt.imshow(sobely)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
laplacian = cv2.Laplacian(frame,cv2.CV_64F)
plt.imshow(laplacian)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
_, frame = cap.read()

cv2.imshow(getLines(frame))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-f62d70be21f9> in <module>
#       1 _, frame = cap.read()
#       2
# ----> 3 cv2.imshow(getLines(frame))
#
# TypeError: imshow() missing required argument 'mat' (pos 2)

# %%
cv2.imshow('lala',getLines(frame))
